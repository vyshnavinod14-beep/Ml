# %% [markdown]
# <a href="https://colab.research.google.com/github/vyshnavinod14-beep/Ml/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
data={'area':[1200,1500,1800,-2400,3000,3500,4000,4500,5000,5500],'bedrooms':[2,3,3,4,5,5,6,6,7,7],'age':[10,5,8,2,1,3,2,4,1,2],'distance':[5,3,4,2,1,2,1,3,2,1],'price':[250,320,340,450,600,650,700,720,800,850]}

# %%
df=pd.DataFrame(data)

# %%
print("\nDATASET\n")
print(df)
# Out:
# DATASET
#
#    area  bedrooms  age  distance  price
# 0  1200         2   10         5    250
# 1  1500         3    5         3    320
# 2  1800         3    8         4    340
# 3 -2400         4    2         2    450
# 4  3000         5    1         1    600
# 5  3500         5    3         2    650
# 6  4000         6    2         1    700
# 7  4500         6    4         3    720
# 8  5000         7    1         2    800
# 9  5500         7    2         1    850

# %%
X=df[['area','bedrooms','age','distance']]

# %%
y=df['price']

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X)

# %%
print("\nMODEL PARAMETERS\n")
# Out:
# MODEL PARAMETERS

# %%
print("intercept:")
print(model.intercept_)
print("\nCoefficients:")
for feature,coef in zip(X.columns,model.coef_):
  print(feature,":",coef)
# Out:
# intercept:
# -2.0121773026535266
#
# Coefficients:
# area : 0.0039027192137843997
# bedrooms : 118.44840439856472
# age : 8.020528868276614
# distance : -16.57903272498052

# %%
print("\nREGRESSION EQUATION\n")
print("Price=")
for feature,coef in zip(X.columns,model.coef_):
  print(f"({coef:.4f}*{feature})+")
  print(model.intercept_)
# Out:
# REGRESSION EQUATION
#
# Price=
# (0.0039*area)+
# -2.0121773026535266
# (118.4484*bedrooms)+
# -2.0121773026535266
# (8.0205*age)+
# -2.0121773026535266
# (-16.5790*distance)+
# -2.0121773026535266

# %%
mse = mean_squared_error(y, y_pred)

r2 = r2_score(y, y_pred)

print("\nEVALUATION METRICS\n")

print("Mean Squared Error (MSE):", round(mse, 4))

print("R² Score:", round(r2, 4))
# Out:
# EVALUATION METRICS
#
# Mean Squared Error (MSE): 565.1335
# R² Score: 0.9862

# %%
new_house = pd.DataFrame({
    'area': [2800],
    'bedrooms': [4],
    'age': [2],
    'distance': [2]
})
predicted_price = model.predict(new_house)

print("\nNEW HOUSE PREDICTION\n")

print("Predicted House Price:",
      round(predicted_price[0], 2))
# Out:
# NEW HOUSE PREDICTION
#
# Predicted House Price: 465.59

# %%
plt.figure(figsize=(8,6))

plt.scatter(y, y_pred, color='blue')

plt.plot([y.min(), y.max()],
         [y.min(), y.max()],
         color='red')

plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")

plt.title("Actual vs Predicted Prices")

plt.grid(True)

plt.show()
